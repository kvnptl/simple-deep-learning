# %% [markdown]
# ### Get the MNIST dataset from Keras

# %%
import tensorflow as tf

(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.mnist.load_data()

print(train_images.shape, train_labels.shape)
print(test_images.shape, test_labels.shape)
# Out:
# 2024-04-13 00:24:59.306671: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-04-13 00:24:59.308456: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-04-13 00:24:59.331839: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-13 00:24:59.796858: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# (60000, 28, 28) (60000,)
# (10000, 28, 28) (10000,)

# %% [markdown]
# #### Show sample images

# %%
from simple_deep_learning.mnist_extended.mnist import display_digits

display_digits(images=train_images, labels=train_labels, num_to_display=20)

# %% [markdown]
# ### Create the semantic segmentation dataset

# %%
import numpy as np
np.random.seed(seed=9)

from simple_deep_learning.mnist_extended.semantic_segmentation import (create_semantic_segmentation_dataset, display_segmented_image,
                                                                       display_grayscale_array, plot_class_masks)

train_x, train_y, test_x, test_y = create_semantic_segmentation_dataset(num_train_samples=100,
                                                                        num_test_samples=10,
                                                                        image_shape=(60, 60),
                                                                        num_classes=5)

# %%
import numpy as np

i = np.random.randint(len(train_x))
print(f'Train image shape: {train_x[i].shape}')
print(f'Train label shape: {train_y[i].shape}')

print(f'Total train samples: {len(train_x)}')
print(f'Total test samples: {len(test_x)}')
# Out:
# Train image shape: (60, 60, 1)
# Train label shape: (60, 60, 5)
# Total train samples: 100
# Total test samples: 10

# %%
import matplotlib.pyplot as plt

# plt.imshow(train_x[0])

print(train_y[0][:, :, 0].shape)
plt.imshow(train_y[0][:, :, 4])
# Out:
# (60, 60)

# %%
from simple_deep_learning.mnist_extended.semantic_segmentation import display_grayscale_array

i = np.random.randint(len(train_x))
display_grayscale_array(array=train_x[i])

# %%
from simple_deep_learning.mnist_extended.semantic_segmentation import plot_class_masks
plot_class_masks(train_y[i])

# %%
from simple_deep_learning.mnist_extended.semantic_segmentation import display_grayscale_array
display_segmented_image(y=train_y[i])
